# %%
import pandas as pd
df = pd.read_csv("football.csv")

# %%
# how big data is??
df.shape
# Out:
# (121, 33)

# %%
# how does data is look like??
# use df.head() or df.sample() or df.tail() but sample is more imp to check or see 5 random rows..
df.sample(5)
# Out:
#      Unnamed: 0  app_temp  clouds  clouds_hi  clouds_low  clouds_mid  \
# 43           43      28.9       5          0           0           0
# 2             2      12.4       4          0           0           0
# 118         118      26.8       8         79           0          11
# 11           11      34.7       2          0           0           0
# 79           79      54.7      58          0          91          97
#
#           datetime  dewpt  dhi  dni  ...        timestamp_utc          ts uv  \
# 43   2025-12-17:05   22.8    0    0  ...  2025-12-17T05:00:00  1765947600  0
# 2    2025-12-15:12    0.7    0    0  ...  2025-12-15T12:00:00  1765800000  0
# 118  2025-12-20:08   21.9    0    0  ...  2025-12-20T08:00:00  1766217600  0
# 11   2025-12-15:21    8.2   54  484  ...  2025-12-15T21:00:00  1765832400  2
# 79   2025-12-18:17   46.6   99  817  ...  2025-12-18T17:00:00  1766077200  2
#
#       vis                                            weather  wind_cdir  \
# ...

# %%
# checking the datatypes of the dataset?/
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 33 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       121 non-null    int64
#  1   app_temp         121 non-null    float64
#  2   clouds           121 non-null    int64
#  3   clouds_hi        121 non-null    int64
#  4   clouds_low       121 non-null    int64
#  5   clouds_mid       121 non-null    int64
#  6   datetime         121 non-null    object
#  7   dewpt            121 non-null    float64
#  8   dhi              121 non-null    int64
#  9   dni              121 non-null    int64
#  10  ghi              121 non-null    int64
#  11  ozone            121 non-null    int64
#  12  pod              121 non-null    object
#  13  pop              121 non-null    int64
#  14  precip           121 non-null    float64
#  15  pres             121 non-null    int64
#  16  rh               121 non-null    int64
# ...

# %%
# checking the missing values in the dataset..
df.isnull().sum() 
# above function will give the number of missing values in a col..
# Out:
# Unnamed: 0         0
# app_temp           0
# clouds             0
# clouds_hi          0
# clouds_low         0
# clouds_mid         0
# datetime           0
# dewpt              0
# dhi                0
# dni                0
# ghi                0
# ozone              0
# pod                0
# pop                0
# precip             0
# pres               0
# rh                 0
# slp                0
# snow               0
# snow_depth         0
# solar_rad          0
# temp               0
# timestamp_local    0
# timestamp_utc      0
# ts                 0
# uv                 0
# vis                0
# weather            0
# wind_cdir          0
# wind_cdir_full     0
# wind_dir           0
# wind_gust_spd      0
# wind_spd           0
# dtype: int64

# %%
# how does data look like mathematically...
df.describe()
# Out:
#        Unnamed: 0    app_temp      clouds   clouds_hi  clouds_low  clouds_mid  \
# count  121.000000  121.000000  121.000000  121.000000  121.000000  121.000000
# mean    60.000000   38.718182   29.768595   39.280992   14.438017   29.438017
# std     35.073732   12.876866   28.553389   45.441578   31.094987   42.955964
# min      0.000000    9.700000    1.000000    0.000000    0.000000    0.000000
# 25%     30.000000   28.600000    4.000000    0.000000    0.000000    0.000000
# 50%     60.000000   38.500000   14.000000    7.000000    0.000000    0.000000
# 75%     90.000000   51.600000   58.000000  100.000000    1.000000   89.000000
# max    120.000000   60.100000   89.000000  100.000000  100.000000  100.000000
#
#             dewpt         dhi         dni         ghi  ...   snow  snow_depth  \
# count  121.000000  121.000000  121.000000  121.000000  ...  121.0       121.0
# mean    27.704959   29.512397  251.859504  123.809917  ...    0.0         0.0
# ...

# %%
# are there duplicates value to remove redundancy in the dataset..?
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# checking the correlation between the cols...
df = df[["app_temp", "clouds", "clouds_hi", "clouds_low", "clouds_mid"]]
df.corr()["app_temp"]
# Out:
# app_temp      1.000000
# clouds        0.729835
# clouds_hi     0.286882
# clouds_low    0.583063
# clouds_mid    0.622178
# Name: app_temp, dtype: float64
