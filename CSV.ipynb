# %%
import pandas as pd

# %%
## for reading any csv file..
# pd.read_csv("name of the file.csv")
## for reading the tsv file(tab sep file) we use the sep arg in the read csv file that make the sep from , to \t
# pd.read_csv("file in tsv.tsv", sep = "\t")
## if the name o fthe columns become the row 1 we use the header arg in the read_csv function of the pandas to make it the name of the cols..
# pd.read_csv("name of the file in csv", header = 1)
## if the name of the col is not there in the dataset in csv..
# pd.read_csv("name of the file in csv", names = ["name of all cols in this list"])
## if the dataset is in encoded in any other lang we have to encode it for to remove the error..
# pd.read_csv("name of the file in csv", encoding = "latin-1 let say")

## to check the number of the not num count and the datatype of alll cols we use .info() function..
# df = pd.read_csv("name of the file in csv").info()


## if we have large dataset having many rows we broke it into the chunks to work on it if we donot have the powerful machine..
# df = pd.read_csv("name of the file in csv", chunksize = let say 5000)
# after chunking the dataset we have to use these cunks with the help of for 
# for chunks in df:
#    print(chunks.shape)  print the shape of the chunks
# these chunks are divided into equal number of rows having the size equal or less than 5000...
