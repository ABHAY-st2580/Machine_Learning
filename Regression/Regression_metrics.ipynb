# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('LR.csv')

# %%
df = df.sample(200)

# %%
plt.scatter(df['x'], df['y'])
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
X = df.iloc[:, 0:1]
Y = df.iloc[:,-1]

# %%
X.shape, Y.shape
# Out:
# ((200, 1), (200,))

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size = 0.2, random_state = 2)

# %%
x_train.shape
# Out:
# (160, 1)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_test
# Out:
# 775     1478.77
# 603      752.31
# 830     2719.85
# 3        171.67
# 14      1382.13
# 130      810.58
# 870       95.81
# 208     1456.55
# 1087    2095.95
# 1050    1883.19
# 1265     306.47
# 1332     938.74
# 1393    1337.66
# 151      425.99
# 1466     290.83
# 1136    1228.31
# 327      594.46
# 690      611.66
# 1066     941.36
# 945     2329.29
# 1271     540.72
# 455      926.97
# 691        6.94
# 1254     931.38
# 942      900.70
# 872      753.76
# 726     1072.37
# 1034    2532.54
# 1172    1715.73
# 567     1806.71
# 296     1377.79
# 1421    2059.32
# 174     2671.18
# 24      2475.14
# 368     1324.27
# 537     1560.34
# 1163    1397.37
# 1077      98.80
# 426     2152.50
# 1409    1091.56
# Name: y, dtype: float64

# %%
lr.predict(x_test.iloc[0].values.reshape(1,1))
# Out:
# C:\Users\abhay\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1468.43528175])

# %%
plt.scatter(df['x'], df['y'])
plt.plot(x_train, lr.predict(x_train), color = 'red')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
m = lr.coef_ #Slope
c = lr.intercept_ #Intercept

# %%
m, c
# Out:
# (array([2.80355797]), np.float64(54.23653672006776))

# %%
m*x_test.iloc[0] + c
# Out:
# x    1468.435282
# Name: 775, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
y_pred = lr.predict(x_test)

# %%
x_test.shape
# Out:
# (40, 1)

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
adjr2 = ((1- r2)*(40 - 1)/(40 - 1 - 1))

# %%
mae
# Out:
# 95.42858471024874

# %%
mse
# Out:
# 16063.025367109882

# %%
rmse
# Out:
# np.float64(126.73999119105967)

# %%
r2
# Out:
# 0.9711988282196015

# %%
adjr2
# Out:
# 0.02955909735356692
