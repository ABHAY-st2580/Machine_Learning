# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as  plt
import seaborn as sns

# %%
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import r2_score

# %%
X = 6 * np.random.rand(1000) - 3
Y = 0.8 * X**2 + 0.5*X + 3 + 2*np.random.randn(1000)

# %%
plt.plot(X, Y, 'b.')
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 32)

# %%
x_train = x_train.reshape(-1,1)
x_test = x_test.reshape(-1,1)

# %%
pf = PolynomialFeatures(degree = 2)

# %%
x_train_trf = pf.fit_transform(x_train)
x_test_trf = pf.transform(x_test)

# %%
x_train[0]
x_train_trf[0]
# Out:
# array([ 1.        , -2.11691845,  4.48134371])

# %%
lr = LinearRegression()
y_train.reshape(-1,1)
y_test.reshape(-1,1)
# Out:
# array([[ 2.89952182],
#        [ 7.73895397],
#        [ 3.97648674],
#        [ 6.79457126],
#        [ 6.4420497 ],
#        [-1.10814731],
#        [ 6.41157552],
#        [ 2.05073675],
#        [12.2878196 ],
#        [ 4.32132868],
#        [ 4.92725989],
#        [ 4.92827978],
#        [ 5.5046302 ],
#        [ 6.45715374],
#        [ 7.01527715],
#        [ 3.159733  ],
#        [ 6.62173823],
#        [11.29582905],
#        [ 8.9168721 ],
#        [ 8.33477402],
#        [ 1.22697309],
#        [ 9.03691692],
#        [ 6.29300912],
#        [-0.35815111],
#        [ 2.40869477],
#        [ 6.51649468],
#        [ 4.68753612],
#        [ 3.32626687],
#        [ 3.72117044],
#        [12.53005298],
#        [ 1.73577843],
#        [ 6.09307173],
#        [ 6.74603684],
#        [ 8.30424354],
#        [ 3.04997051],
#        [ 1.72727328],
#        [ 1.30882971],
#        [ 9.38577523],
#        [ 2.39316259],
#        [ 5.83904926],
#        [ 3.66933071],
#        [ 3.21774181],
#        [ 2.12051401],
#        [ 3.81308061],
#        [ 7.99089595],
#        [ 4.09260515],
#        [ 2.53231061],
#        [ 8.88241911],
#        [ 9.14241592],
#        [ 3.82100642],
#        [ 4.74434155],
#        [10.61125581],
#        [ 4.4240493 ],
#        [ 7.52056735],
#        [ 5.79545298],
#        [ 4.570745  ],
#        [10.39533583],
#        [ 4.06621882],
#        [ 2.00677921],
#        [ 8.01275933],
#        [ 5.90988407],
#        [ 3.39225175],
#        [ 8.79532956],
#        [ 6.47989775],
#        [ 8.77417308],
#        [ 6.83318666],
#        [11.61311516],
#        [ 8.89147731],
#        [ 4.39492917],
#        [ 8.15922477],
#        [ 3.53649   ],
#        [ 2.2308795 ],
#        [ 5.44465668],
#        [ 3.44598998],
#        [ 6.17251896],
#        [ 3.25749832],
#        [ 2.665462  ],
#        [ 6.15141664],
#        [ 9.17261885],
#        [ 4.70316459],
#        [ 5.0706308 ],
#        [ 1.99050968],
#        [10.90144894],
#        [ 3.55944096],
#        [ 3.39126929],
#        [ 6.57040895],
#        [ 5.5074721 ],
#        [ 2.40422058],
#        [ 4.7814763 ],
#        [ 4.38736139],
#        [ 7.26591015],
#        [ 2.90716572],
#        [ 6.60023805],
#        [ 2.92984219],
#        [ 7.18989809],
#        [ 5.86471322],
#        [ 8.16788757],
#        [ 5.78157932],
#        [ 7.27729568],
#        [ 2.62808315],
#        [ 6.14759299],
#        [ 5.83929798],
#        [ 2.43300696],
#        [ 5.81867066],
#        [ 7.10023409],
#        [ 1.66880821],
#        [ 2.88958185],
#        [ 1.25726152],
#        [ 6.28364282],
#        [ 6.91386793],
#        [ 4.38180837],
#        [ 0.30662222],
#        [ 7.65438432],
#        [ 7.90194646],
#        [ 6.37127273],
#        [ 1.08541312],
#        [ 2.35068533],
#        [ 4.63795499],
#        [ 2.94812189],
#        [ 4.30653646],
#        [ 2.97168708],
#        [ 8.6994695 ],
#        [ 3.63378126],
#        [ 2.96391843],
#        [11.42802141],
#        [ 7.12634094],
#        [ 5.83886153],
#        [ 2.32428984],
#        [10.02883668],
#        [ 4.24532089],
#        [ 0.87414021],
#        [ 4.9358807 ],
#        [ 6.78307774],
#        [ 9.33849845],
#        [ 4.15214702],
#        [ 1.4908034 ],
#        [ 5.02106631],
#        [ 4.18050566],
#        [ 5.85096407],
#        [ 3.23738822],
#        [ 6.26636706],
#        [ 7.90028848],
#        [ 5.89202664],
#        [ 4.18479784],
#        [ 4.6712911 ],
#        [ 5.12310342],
#        [14.19900611],
#        [ 6.042901  ],
#        [ 6.97275421],
#        [ 3.35532923],
#        [11.36234638],
#        [ 3.34524853],
#        [ 3.63670815],
#        [ 7.38658467],
#        [ 4.01862418],
#        [10.2444724 ],
#        [ 4.32989018],
#        [ 6.56494185],
#        [ 9.92139752],
#        [ 4.34840825],
#        [ 5.34220444],
#        [ 9.05277752],
#        [ 1.62840847],
#        [ 2.48705304],
#        [ 6.25805896],
#        [ 3.15059925],
#        [ 9.7577337 ],
#        [ 6.64064185],
#        [ 4.49085098],
#        [11.80582546],
#        [ 3.31938799],
#        [ 4.81858973],
#        [ 3.85198523],
#        [ 6.00192191],
#        [ 6.79431676],
#        [-0.35204486],
#        [ 6.63019388],
#        [ 4.21364937],
#        [10.96691422],
#        [ 4.43165026],
#        [ 4.59903513],
#        [ 5.89935369],
#        [ 7.1078612 ],
#        [ 7.34196218],
#        [ 8.51904722],
#        [ 6.46485332],
#        [ 6.61009469],
#        [ 6.98928692],
#        [ 4.22825268],
#        [ 2.58360798],
#        [ 9.08818247],
#        [11.34404942],
#        [ 7.96395953],
#        [ 3.54346579],
#        [ 7.32706823],
#        [10.5510351 ],
#        [ 2.6296494 ],
#        [ 5.03407593],
#        [ 7.79383722],
#        [ 6.68060711]])

# %%
lr.fit(x_train_trf, y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([0.        , 0.51470058, 0.79755781])

# %%
lr.intercept_
# Out:
# np.float64(3.122326381379024)

# %%
y_pred = lr.predict(x_test_trf)

# %%
x_new = np.linspace(-3,3,1000).reshape(1000,1)
x_new_poly = pf.transform(x_new)

# %%
y_new = lr.predict(x_new_poly)

# %%
lp = LinearRegression()
lp.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
plt.plot(x_train, y_train, 'b.')
plt.plot(x_new, y_new, 'r-', linewidth = 1)
# plt.plot(x_test, y_pred, 'g-')
# plt.plot(x_new, lp.predict(x_new), 'y-', linewidth = 2)
plt.show()
