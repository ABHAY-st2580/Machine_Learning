# %%
import pandas as pd

# %%
## for reading the json file...
# pd.read_json("name of the file in json")
## if we have the url where the json data is present we can simple write the url in this function to read the json file format...
# pd.read_json("url link where json data is there")

# %%
# !pip install pandas sqlalchemy pymysql psycopg2-binary
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 1.2 MB/s eta 0:00:02
#    --------- ------------------------------ 0.5/2.1 MB 1.2 MB/s eta 0:00:02
#    --------- ------------------------------ 0.5/2.1 MB 1.2 MB/s eta 0:00:02
#    -------------- ------------------------- 0.8/2.1 MB 719.7 kB/s eta 0:00:02
#    ------------------- -------------------- 1.0/2.1 MB 862.6 kB/s eta 0:00:02
#    ------------------------ --------------- 1.3/2.1 MB 925.5 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 910.7 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 975.7 kB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.0 MB/s  0:00:02
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
# ...

# %%
import pandas as pd
from sqlalchemy import create_engine
# for data connection making the engine obj..
engine = create_engine(
    "mysql+pymysql://root:abhayst2580@localhost:3306/company"
)
query = "SELECT * FROM employee"
df = pd.read_sql(query, engine)

print(df.head())
# Out:
#       Fname Minit    Lname        Ssn       Bdate                   Address  \
# 0      John     B    Smith  123456789  1965-01-09  731 Fondren, Houston, TX
# 1  Franklin     T     Wong  333445555  1955-12-08     638 Voss, Houston, TX
# 2     Joyce     A  English  453453453  1972-07-31    5631 Rice, Houston, TX
# 3    Ramesh     K  Narayan  666884444  1962-09-15  975 Fire Oak, Humble, TX
# 4     James     E     Borg  888665555  1937-11-10    450 Stone, Houston, TX
#
#   Sex   Salary  Super_ssn  Dno
# 0   M  33000.0  333445555    5
# 1   M  40000.0  888665555    5
# 2   F  27500.0  333445555    5
# 3   M  38000.0  333445555    5
# 4   M  55000.0       None    1
